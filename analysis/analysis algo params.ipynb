# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("ticks")
# sns.set(font_scale=1.5)

# %%
data = pd.read_excel('../results/node reduction.xlsx')
data
# Out:
#            city  pruning  iterations  threshold  \
# 0   Winterswijk        0           1          0
# 1   Winterswijk        0           1       1000
# 2   Winterswijk        0        1000          0
# 3   Winterswijk        0        1000       1000
# 4   Winterswijk        1           1          0
# 5   Winterswijk        1           1       1000
# 6   Winterswijk        1        1000          0
# 7   Winterswijk        1        1000       1000
# 8     Manhattan        0           1          0
# 9     Manhattan        0           1       1000
# 10    Manhattan        0        1000          0
# 11    Manhattan        0        1000       1000
# 12    Manhattan        1           1          0
# 13    Manhattan        1           1       1000
# 14    Manhattan        1        1000          0
# 15    Manhattan        1        1000       1000
# 16      Utrecht        0           1          0
# 17      Utrecht        0           1       1000
# ...

# %%
with sns.axes_style("whitegrid"):
    sns.scatterplot(data, x='% node reduction', y='% degradation', hue='city', style='pruning', size='iterations', legend="full")
    plt.legend(loc=(1.04, 0.4))
    plt.ylim(-100,5)
    # plt.xlim(-5, 50)
    
    plt.savefig(f'figs/degradation_default_algo.png', bbox_inches='tight', dpi=300)

# %%
what happens the to number of permutations after coarsening?
# Out:
# Object `coarsening` not found.
